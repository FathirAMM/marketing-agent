# %%
from dotenv import load_dotenv
import os
load_dotenv()

QDRANT_URL = os.getenv("QDRANT_URL")
QDRANT_API_KEY = os.getenv("QDRANT_API_KEY")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
from qdrant_client import QdrantClient
# Increase timeout to 60 seconds (default is usually 5 or 10)
qdrant_client = QdrantClient(
    url=QDRANT_URL, 
    api_key=QDRANT_API_KEY,
    timeout=60.0   
)

print(qdrant_client.get_collections())
# Out:
# collections=[CollectionDescription(name='dilmah_wishes')]

# %%
# Initialize OpenAI Embeddings
from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small" # Efficient and high performance
)

# %%
from langchain_qdrant import QdrantVectorStore

vector_store = QdrantVectorStore(
    client=qdrant_client,
    collection_name="dilmah_wishes",
    embedding=embeddings,
)

# %%
query = "Dilma’s Dream Escape competition?"

# k=1 returns the top 1 result
results = vector_store.similarity_search(query, k=3)

for doc in results:
    print(f"Content: {doc.page_content}")
    print(f"Metadata: {doc.metadata}")
    print("--------------------------------")
# Out:
# Content: Dilma’s “Dream Escape” competition will award 20 winners a luxury trip for two to the Ceylon Tea region, and the brand is marking 40 years of tea‐time partnerships with Australians while allocating 15 % of its profits to conservation projects such as the Elephant Transit Home. The Elephant Transit Home, situated in Uda Walawe National Park about a 4.5‐hour drive from Colombo, rescues orphaned Asian elephants, rehabilitates them (feeding them five times daily) and releases them in social groups; it has been supported by Dilma Conservation since 2007 and also cares for a 15‐year‐old bull with a prosthetic leg that cannot be re‐wilded. Human
# Metadata: {'video_title': 'Channel 7 Australia’s visit to the Elephant Transit Home', 'video_url': 'https://www.youtube.com/watch?v=-yn2ZBmr0xA', '_id': 'cefa7e0a-6deb-42f0-a6d1-32dc80cb0b9c', '_collection_name': 'dilmah_wishes'}
# --------------------------------
# Content: Dilma is running a tea‐inspired dessert competition that requires participants to create a dessert or dessert cocktail using a specific Dilma tea, submit a photo or video, the recipe, and a rationale explaining the tea choice and its function, and include the used tea pack in the submission. Entries are accepted continuously until October, with no limit on the number of submissions per participant. From all entries, 25 winners will receive a “Tee Deserved” gift pack, and five grand‐prize winners will receive a two‐night stay for two adults at a five‐star hotel in their country. Additional details are provided via the competition link.
# Metadata: {'video_title': 'Mixologist- Robert Schinkel Spills the Dessert Tea on the Upcoming Dilmah Challenge', 'video_url': 'https://www.youtube.com/watch?v=oyouwN41oU4', '_id': '86978aa7-3d37-4dfc-9e5f-13dd544a7097', '_collection_name': 'dilmah_wishes'}
# --------------------------------
# Content: The “Dilma’s Dream Escape” competition, ending today at 3 p.m. Eastern, offers 20 trips for two to Sri Lanka, with flights provided by Sri Lankan Airlines. Winners travel nonstop from Sydney to Colombo on an Airbus A330‐300, a 10‐hour‐30‐minute flight that arrives at night to allow immediate holiday start. Sri Lankan Airlines highlights its hospitable crew, direct connectivity, affordable pricing, and access to Sri Lanka’s wildlife, nightlife, and cuisine. The promotion directs participants to submit a 25‐word entry on themorningshow.com.au, with the winning pair announced live on air.
# Metadata: {'video_title': 'Dilmah’s Dream Escape to Resplendent Ceylon with SriLankan Airlines', 'video_url': 'https://www.youtube.com/watch?v=M481hMktnRc', '_id': '86c1643f-cc58-4357-97a4-ee57e7465cbb', '_collection_name': 'dilmah_wishes'}
# --------------------------------
